# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv', index_col=0)

# %%
df.head()
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)      ?
# 149190           55629189        Caucasian  Female  [10-20)      ?
# 64410            86047875  AfricanAmerican  Female  [20-30)      ?
# 500364           82442376        Caucasian    Male  [30-40)      ?
# 16680            42519267        Caucasian    Male  [40-50)      ?
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
#
#               admission_source_id  time_in_hospital payer_code  ...  \
# encounter_id                                                    ...
# ...

# %%
df
# Out:
#               patient_nbr  gender payer_code         medical_specialty  \
# encounter_id
# 2278392           8222157  Female          ?  Pediatrics-Endocrinology
# 149190           55629189  Female          ?                         ?
# 64410            86047875  Female          ?                         ?
# 500364           82442376    Male          ?                         ?
# 16680            42519267    Male          ?                         ?
# ...                   ...     ...        ...                       ...
# 443847548       100162476    Male         MC                         ?
# 443847782        74694222  Female         MC                         ?
# 443854148        41088789    Male         MC                         ?
# 443857166        31693671  Female         MC           Surgery-General
# 443867222       175429310    Male          ?                         ?
#
#               num_lab_procedures  num_procedures  num_medications  \
# encounter_id
# ...

# %%
df.drop(['glipizide','acetohexamide','glimepiride','chlorpropamide','nateglinide','repaglinide','metformin','A1Cresult','max_glu_serum','number_diagnoses','diag_3','diag_2','diag_1','number_inpatient'], axis=1, inplace=True)

# %%
df
# Out:
#               patient_nbr  gender payer_code         medical_specialty  \
# encounter_id
# 2278392           8222157  Female          ?  Pediatrics-Endocrinology
# 149190           55629189  Female          ?                         ?
# 64410            86047875  Female          ?                         ?
# 500364           82442376    Male          ?                         ?
# 16680            42519267    Male          ?                         ?
# ...                   ...     ...        ...                       ...
# 443847548       100162476    Male         MC                         ?
# 443847782        74694222  Female         MC                         ?
# 443854148        41088789    Male         MC                         ?
# 443857166        31693671  Female         MC           Surgery-General
# 443867222       175429310    Male          ?                         ?
#
#               num_lab_procedures  num_procedures  num_medications  \
# encounter_id
# ...

# %%
df.drop(['readmitted','examide','tolazamide','troglitazone','miglitol','acarbose','rosiglitazone','pioglitazone','tolbutamide','glyburide','number_emergency','number_outpatient','num_medications','num_procedures','medical_specialty','payer_code','patient_nbr'], axis=1, inplace=True)

# %%
df
# Out:
#               gender  num_lab_procedures
# encounter_id
# 2278392       Female                  41
# 149190        Female                  59
# 64410         Female                  11
# 500364          Male                  44
# 16680           Male                  51
# ...              ...                 ...
# 443847548       Male                  51
# 443847782     Female                  33
# 443854148       Male                  53
# 443857166     Female                  45
# 443867222       Male                  13
#
# [101766 rows x 2 columns]

# %%
duplicates=df.duplicated(subset=None, keep='first')
print(duplicates)
# Out:
# encounter_id
# 2278392      False
# 149190       False
# 64410        False
# 500364       False
# 16680        False
#              ...
# 443847548     True
# 443847782     True
# 443854148     True
# 443857166     True
# 443867222     True
# Length: 101766, dtype: bool

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
df
# Out:
#                        gender  num_lab_procedures
# encounter_id
# 2278392                Female                  41
# 149190                 Female                  59
# 64410                  Female                  11
# 500364                   Male                  44
# 16680                    Male                  51
# ...                       ...                 ...
# 257364294     Unknown/Invalid                  59
# 274455804                Male                 121
# 282942948              Female                 108
# 309003956              Female                 126
# 356032760              Female                 118
#
# [229 rows x 2 columns]

# %%
df.count()
# Out:
# gender                229
# num_lab_procedures    229
# dtype: int64

# %%
df.groupby(['gender']).sum()
# Out:
#                  num_lab_procedures
# gender
# Female                         6368
# Male                           6599
# Unknown/Invalid                 102
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['num_lab_procedures'].plot(kind='hist', bins=20, title='num_lab_procedures')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['num_lab_procedures'].plot(kind='line', figsize=(8, 4), title='num_lab_procedures')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.groupby(['gender'])["num_lab_procedures"].sum().sort_values(ascending = False).plot(kind="bar")
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# I wanted to compare the lab procedures between males and females with regards to Diabetes. I came to the conclusion that men have more lab procedures done vs women, but the difference between the two is not that significant when seeing it visualized.
